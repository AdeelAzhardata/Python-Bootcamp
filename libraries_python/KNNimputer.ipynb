# %% [markdown]
# # KNN IMPUTER PRACTICE

# %%
import pandas as pd
import sklearn
import seaborn as sns

# %% [markdown]
# LOAD DATASET

# %%
df = pd.read_csv('titanic.csv')

# %% [markdown]
# CHECKING MISSING VALUES AND SORTING

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# HANDLING CATEGORICAL MISSING VALUES

# %%
df['embarked'].fillna(df['embarked'].mode()[0] , inplace = True)
df['embark_town'].fillna(df['embark_town'].mode()[0] , inplace = True)
df = df.drop(columns=['deck'])
df.isna().sum().sort_values(ascending=False)

# %%
df.info()

# %%
#SAVING NUMERICAL COLUMNS
# num_cols = df.select_dtypes(include =['int64','float64']).columns

# %% [markdown]
# SCALING DATA

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaled_data = scaler.fit_transform(df[num_cols])

# %% [markdown]
# IMPUTING NUMERICAL MISSING DATA USING KNN IMPUTER

# %%
# from sklearn.impute import KNNImputer

# imputer = KNNImputer(n_neighbors=3 , weights='distance')
# imputed_scaled_data = imputer.fit_transform(scaled_data)

# %% [markdown]
# INVERSE SCALING

# %%
# imputed_data = scaler.inverse_transform(imputed_scaled_data)
# df[num_cols]= pd.DataFrame(imputed_data , columns=num_cols)

# %%
# df.isna().sum()
# df.head(20)

# %%
num_col = df.select_dtypes(include=['int64','float64']).columns

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df[num_col])

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=3, weights='distance')
imputed_scaled_data = imputer.fit_transform(scaled_data)

# %%
imputed_data = scaler.inverse_transform(imputed_scaled_data)
df[num_col]=pd.DataFrame(imputed_data , columns=num_col)

# %%
df.isna().sum()
sns.boxplot(x=df['age'])
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(x=df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['sex']=le.fit_transform(df['sex'])
