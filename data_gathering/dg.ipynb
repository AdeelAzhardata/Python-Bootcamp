# %%
import pandas
import wbdata

# %%
import faostat

# %% [markdown]
# FAOSTAT

# %%
mypars = {'element':[2312, 2313],'item':'221'}
data = faostat.get_data('QCL' , pars=mypars)
data

# %%
df = faostat.get_data_df('QCL', pars=mypars)
df.columns

# %%
df = df[['Domain','Area','Element','Item','Year','Unit','Value']]
df.to_csv('./datasets/faostat_data.csv',index=False)

# %% [markdown]
# YAHOO FINANCE

# %%
import yfinance as yf

# %%
ticker = 'BTC-USD'

# %%
start_date = '2015-01-01'
end_date = '2024-01-01'

# %%
df_btcusd = yf.download(ticker,start=start_date, end=end_date)
df_btcusd.head(50)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker         BTC-USD     BTC-USD     BTC-USD     BTC-USD    BTC-USD
# Date
# 2015-01-01  314.248993  320.434998  314.002991  320.434998    8036550
# 2015-01-02  315.032013  315.838989  313.565002  314.079010    7860650
# 2015-01-03  281.082001  315.149994  281.082001  314.846008   33054400
# 2015-01-04  264.195007  287.230011  257.612000  281.145996   55629100
# 2015-01-05  274.473999  278.341003  265.084015  265.084015   43962800
# 2015-01-06  286.188995  287.553009  272.696014  274.610992   23245700
# 2015-01-07  294.337006  298.753998  283.079010  286.076996   24866800
# 2015-01-08  283.348999  294.135010  282.174988  294.135010   19982500
# 2015-01-09  290.407990  291.114014  280.532990  282.382996   18718600
# 2015-01-10  274.795990  288.127014  273.966003  287.303009   15264300
# ...

# %%
df_btcusd.to_csv("btcusd.csv")
