# %% [markdown]
# # Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("houseprice.csv")
df.columns
# Out:
# Index(['size_sqft', 'bedrooms', 'age_years', 'price'], dtype='object')

# %%
df.head()
# Out:
#    size_sqft  bedrooms  age_years   price
# 0        800         1         20  120000
# 1        900         2         18  135000
# 2       1000         2         15  150000
# 3       1100         3         12  165000
# 4       1200         3         10  180000

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
X = df[['size_sqft','bedrooms','age_years']]
y = df[['price']]
model = LinearRegression()
model.fit(X,y)
model.predict([[1200,2,30]])
# Out:
# c:\adeelrana\envs\ml_algo\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[198576.97712762]])

# %%
sns.lmplot(
    x="bedrooms",
    y="price",
    data=df,

)

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
df = pd.read_csv('tts.csv')

# %%
df
# Out:
#    Hours_Studied  Attendance  Previous_Score Final_Result
# 0              2          60              45         Fail
# 1              4          70              55         Fail
# 2              6          75              65         Pass
# 3              8          80              70         Pass
# 4              3          65              50         Fail
# 5              5          72              60         Pass
# 6              7          78              68         Pass
# 7              1          50              40         Fail
# 8              9          85              75         Pass
# 9             10          90              80         Pass

# %%
X = df.drop("Final_Result",axis=1)
y = df['Final_Result']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
#    Hours_Studied  Attendance  Previous_Score
# 0              2          60              45
# 7              1          50              40
# 2              6          75              65
# 9             10          90              80
# 4              3          65              50
# 3              8          80              70
# 6              7          78              68
#    Hours_Studied  Attendance  Previous_Score
# 8              9          85              75
# 1              4          70              55
# 5              5          72              60
# 0    Fail
# 7    Fail
# 2    Pass
# 9    Pass
# 4    Fail
# 3    Pass
# 6    Pass
# Name: Final_Result, dtype: object
# 8    Pass
# 1    Fail
# 5    Pass
# Name: Final_Result, dtype: object

# %% [markdown]
# # Regression Matrics

# %%
from sklearn.metrics import root_mean_squared_error , r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("RM.csv")
df.columns
# Out:
# Index(['Hours_Studied', 'Attendance', 'Previous_Score', 'Final_Score'], dtype='object')

# %%
X = df.drop("Final_Score" , axis=1)
y = df['Final_Score']

X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.30,random_state=1)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# # MSE and RMSE

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print("MEAN SQUARED ERROR = " , mse)
print("ROOT MEAN SQUARED ERROR = " , rmse)
# Out:
# MEAN SQUARED ERROR =  2.160602314366226
# ROOT MEAN SQUARED ERROR =  1.4698987428956547

# %% [markdown]
# # R2 score

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print("R² Score:", r2)
# Out:
# R² Score: 0.9802634652836376

# %% [markdown]
# # MAE

# %%
from sklearn.metrics import mean_absolute_error , r2_score

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)
# Out:
# MAE: 1.1522157996146436

# %% [markdown]
# # Classification matrics

# %%
model = LogisticRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# # MATRICS
# ACCURACY , PRECISION , RECALL , F1 , CONFUSION

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, pos_label='Pass')
recall = recall_score(y_test, y_pred, pos_label='Pass')
f1 = f1_score(y_test, y_pred, pos_label='Pass')
cm = confusion_matrix(y_test,y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
print("Confusion:", cm )
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Confusion: [[1 0]
#  [0 2]]
